# %%
t1=(1,2,3)
t2=(4,5,6)
print(t1+t2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
nums=(15,8,22,5,13,30)
print(max(nums),min(nums),sum(nums))
# Out:
# 30 5 93

# %%
data=(('Alice',25),('Bob',30))
for n,a in data:
    print(n,a)
# Out:
# Alice 25
# Bob 30

# %%
t=(1,2,3,2,4,1,2)
f={}
for i in t:
    f[i]=f.get(i,0)+1
print(f)
# Out:
# {1: 2, 2: 3, 3: 1, 4: 1}
